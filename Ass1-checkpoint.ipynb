# %%
import pandas as pd
data = pd.read_csv('C:/Users/admin/Desktop/DWDM Codes/DWDM Ass1/WorldCupMatches.csv')
data.head() #...head shows first five rows
#data.tail()  ...tail shows last five elements()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %%
data.isnull().sum()
# Out:
# Year                    3720
# Datetime                3720
# Stage                   3720
# Stadium                 3720
# City                    3720
# Home Team Name          3720
# Home Team Goals         3720
# Away Team Goals         3720
# Away Team Name          3720
# Win conditions          3720
# Attendance              3722
# Half-time Home Goals    3720
# Half-time Away Goals    3720
# Referee                 3720
# Assistant 1             3720
# Assistant 2             3720
# RoundID                 3720
# MatchID                 3720
# Home Team Initials      3720
# Away Team Initials      3720
# dtype: int64

# %%
data.fillna(0,inplace=True)  #replaces all null values by 0
data.isnull().sum()
# Out:
# Year                    0
# Datetime                0
# Stage                   0
# Stadium                 0
# City                    0
# Home Team Name          0
# Home Team Goals         0
# Away Team Goals         0
# Away Team Name          0
# Win conditions          0
# Attendance              0
# Half-time Home Goals    0
# Half-time Away Goals    0
# Referee                 0
# Assistant 1             0
# Assistant 2             0
# RoundID                 0
# MatchID                 0
# Home Team Initials      0
# Away Team Initials      0
# dtype: int64

# %%
print(len(data))
data=data.drop_duplicates()  #removes all the duplicate entries
print(len(data))
# Out:
# 4572
# 837

# %%
data['Stadium']=data['Stadium'].str.upper()  #Converts the whole column to Capital
data.head()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         POCITOS  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  PARQUE CENTRAL  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  PARQUE CENTRAL  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         POCITOS  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  PARQUE CENTRAL  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(data['Attendance'],color='blue')
plt.xlabel('Attendance')
plt.ylabel('No. of teams')
# Out:
# Text(0, 0.5, 'No. of teams')

# %%
data.columns  #shows all the columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %%
data.corr()  #shows correlation of the column
# Out:
#                           Year  Home Team Goals  Away Team Goals  Attendance  \
# Year                  1.000000        -0.079792         0.055251    0.154946
# Home Team Goals      -0.079792         1.000000         0.015866   -0.109783
# Away Team Goals       0.055251         0.015866         1.000000   -0.027013
# Attendance            0.154946        -0.109783        -0.027013    1.000000
# Half-time Home Goals -0.061690         0.730186        -0.002615   -0.117724
# Half-time Away Goals  0.026766        -0.003774         0.679178   -0.037861
# RoundID               0.123824        -0.113167        -0.004752    0.076351
# MatchID               0.209358        -0.186878         0.087616    0.138473
#
#                       Half-time Home Goals  Half-time Away Goals   RoundID  \
# Year                             -0.061690              0.026766  0.123824
# Home Team Goals                   0.730186             -0.003774 -0.113167
# ...

# %%
import seaborn as sns   #seaborn used for heatmaps
nyc_chart = sns.heatmap(data.corr())   #through corrleation draw heatmap

# %%
import seaborn as sns
nyc_chart = sns.heatmap(data.corr(),annot=True)  #annot = true shows the corr values in the heat map

# %%
sns.distplot(data['Attendance'])

# %%
pd.cut(data['Attendance'],4)  #cuts the values into specific ranges
# Out:
# 0      (-0.001, 0.25]
# 1      (-0.001, 0.25]
# 2      (-0.001, 0.25]
# 3      (-0.001, 0.25]
# 4      (-0.001, 0.25]
#             ...
# 832       (0.25, 0.5]
# 833    (-0.001, 0.25]
# 834       (0.25, 0.5]
# 835       (0.25, 0.5]
# 852               NaN
# Name: Attendance, Length: 837, dtype: category
# Categories (4, interval[float64]): [(-0.001, 0.25] < (0.25, 0.5] < (0.5, 0.75] < (0.75, 1.0]]

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler


scaler = MinMaxScaler()



data[['Attendance']] = scaler.fit_transform(data[['Attendance']])
data.head()
# Out:
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# F:\Anaconda\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# ...

# %%
from scipy.stats import zscore
data[['Home Team Goals']].apply(zscore)  #finds zscore
# Out:
#      Home Team Goals
# 0           1.345726
# 1           0.727858
# 2           0.109991
# 3           0.727858
# 4          -0.507877
# 5           0.727858
# 6           1.345726
# 7           0.727858
# 8          -0.507877
# 9          -0.507877
# 10          2.581461
# 11          1.345726
# 12         -0.507877
# 13          1.345726
# 14          0.727858
# 15          2.581461
# 16          2.581461
# 17          1.345726
# 18          0.727858
# 19          1.345726
# 20          0.727858
# 21          0.727858
# 22          1.963593
# 23          0.727858
# 24          3.199328
# 25          0.109991
# 26          0.727858
# 27          0.109991
# 28         -0.507877
# 29          0.109991
# ..               ...
# 807        -0.507877
# 808        -1.125744
# 809        -1.125744
# 810        -0.507877
# 811         0.109991
# 812         0.109991
# 813         0.727858
# 814        -1.125744
# 815        -1.125744
# 816        -1.125744
# 817         0.109991
# ...
